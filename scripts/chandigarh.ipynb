# %%
import os
import fitz
import re
from glob import glob
import pandas as pd
import tarfile

# %%
### From parse_in_rolls

COLUMNS = ["number","id", "elector_name", "father_or_husband_name", "relationship", "house_no", "age", "sex", "ac_name", "parl_constituency", "part_no", "year", "state", "filename", "main_town", "police_station", "mandal", "revenue_division", "district", "pin_code", "polling_station_name", "polling_station_address", "net_electors_male", "net_electors_female", "net_electors_third_gender", "net_electors_total","original_or_amendment"]

# %%
INPUT_FILE = '/opt/data/in-electoral-rolls/chandigarh_pdfs.tar.gz'

# %%
rows = []
with tarfile.open(INPUT_FILE, "r:gz") as tar:
    members = tar.getmembers()[1:]
    print('Total PDF files: %d' % len(members))
    for i, t in enumerate(members):
        fn = t.name
        with tar.extractfile(t) as f:
            pdf_data = f.read()
        doc = fitz.open('pdf', pdf_data)
        for p in doc:
            text = p.getText()
            #print(text)
            for m in re.finditer(r'(?<=\n)(.*?\n\d+\n.*?\nनाम :(.*?\nहै।))', '\n' + text, flags=re.DOTALL):
                box = m.group(1)
                #print(box)
                #print('-'*50)
                if True:
                    elector_name = re.findall(r'(.*?)\d+', box, flags=re.S)[0].strip().replace('\n', ' ')
                    number = re.findall(r'.*?(\d+)', box, flags=re.S)[0].strip()
                    _id = re.findall(r'.*?\d+\n(.*?)\n', box, flags=re.S)[0].strip()
                    a = re.findall(r'नाम :\n(.*?)\nमकान  नं. :', box, flags=re.S)[0].strip().split(':')
                    relationship = a[0].strip()
                    father_or_husband_name = a[1].strip()
                    house_no = re.findall(r'मकान  नं. :(.*?)आयु', box, flags=re.S)[0].strip()
                    age = re.findall(r'आयु :(.*?)िलग', box, flags=re.S)[0].strip()
                    sex = re.findall(r'लग : (.*?)फोटो', box, flags=re.S)[0].strip()
                    data = {'filename': os.path.basename(fn),
                            'number': number,
                            'id': _id,
                            'elector_name': elector_name,
                            'father_or_husband_name': father_or_husband_name,
                            'relationship': relationship,
                            'house_no': house_no,
                            'age': age,
                            'sex': sex,
                           }
                    rows.append(data)
        print(i + 1, fn, len(rows))
        #break
# Out:
# Total PDF files: 527
# 1 chandigarh_pdfs/w0010117.pdf 1243
# 2 chandigarh_pdfs/w0010379.pdf 2313
# 3 chandigarh_pdfs/w0010100.pdf 2860
# 4 chandigarh_pdfs/w0010114.pdf 3915
# 5 chandigarh_pdfs/w0010051.pdf 4819
# 6 chandigarh_pdfs/w0010196.pdf 5949
# 7 chandigarh_pdfs/w0010483.pdf 7156
# 8 chandigarh_pdfs/w0010255.pdf 8237
# 9 chandigarh_pdfs/w0010024.pdf 9309
# 10 chandigarh_pdfs/w0010249.pdf 10347
# 11 chandigarh_pdfs/w0010173.pdf 11265
# 12 chandigarh_pdfs/w0010131.pdf 12426
# 13 chandigarh_pdfs/w0010362.pdf 13403
# 14 chandigarh_pdfs/w0010381.pdf 14589
# 15 chandigarh_pdfs/w0010516.pdf 15794
# 16 chandigarh_pdfs/w0010190.pdf 16489
# 17 chandigarh_pdfs/w0010313.pdf 17657
# 18 chandigarh_pdfs/w0010140.pdf 18872
# 19 chandigarh_pdfs/w0010432.pdf 19864
# 20 chandigarh_pdfs/w0010060.pdf 21255
# 21 chandigarh_pdfs/w0010412.pdf 22328
# 22 chandigarh_pdfs/w0010285.pdf 23456
# 23 chandigarh_pdfs/w0010076.pdf 24181
# 24 chandigarh_pdfs/w0010324.pdf 25403
# 25 chandigarh_pdfs/w0010164.pdf 26597
# 26 chandigarh_pdfs/w0010052.pdf 27581
# 27 chandigarh_pdfs/w0010455.pdf 28499
# 28 chandigarh_pdfs/w0010106.pdf 29359
# 29 chandigarh_pdfs/w0010026.pdf 30339
# 30 chandigarh_pdfs/w0010289.pdf 31591
# 31 chandigarh_pdfs/w0010211.pdf 32820
# 32 chandigarh_pdfs/w0010266.pdf 33921
# 33 chandigarh_pdfs/w0010215.pdf 35098
# 34 chandigarh_pdfs/w0010308.pdf 36086
# 35 chandigarh_pdfs/w0010107.pdf 37023
# 36 chandigarh_pdfs/w0010008.pdf 38181
# 37 chandigarh_pdfs/w0010269.pdf 39330
# 38 chandigarh_pdfs/w0010235.pdf 40440
# 39 chandigarh_pdfs/w0010361.pdf 41608
# 40 chandigarh_pdfs/w0010059.pdf 42909
# 41 chandigarh_pdfs/w0010435.pdf 43889
# 42 chandigarh_pdfs/w0010135.pdf 45043
# 43 chandigarh_pdfs/w0010058.pdf 45852
# 44 chandigarh_pdfs/w0010142.pdf 46780
# 45 chandigarh_pdfs/w0010081.pdf 47608
# 46 chandigarh_pdfs/w0010203.pdf 48523
# 47 chandigarh_pdfs/w0010397.pdf 49720
# 48 chandigarh_pdfs/w0010193.pdf 50662
# 49 chandigarh_pdfs/w0010136.pdf 51883
# 50 chandigarh_pdfs/w0010099.pdf 52615
# 51 chandigarh_pdfs/w0010287.pdf 53812
# 52 chandigarh_pdfs/w0010522.pdf 54953
# 53 chandigarh_pdfs/w0010145.pdf 55875
# 54 chandigarh_pdfs/w0010264.pdf 57027
# 55 chandigarh_pdfs/w0010352.pdf 58173
# 56 chandigarh_pdfs/w0010141.pdf 59100
# 57 chandigarh_pdfs/w0010477.pdf 60073
# 58 chandigarh_pdfs/w0010138.pdf 61263
# 59 chandigarh_pdfs/w0010240.pdf 62492
# 60 chandigarh_pdfs/w0010251.pdf 63635
# 61 chandigarh_pdfs/w0010387.pdf 64767
# 62 chandigarh_pdfs/w0010501.pdf 65868
# 63 chandigarh_pdfs/w0010110.pdf 67100
# 64 chandigarh_pdfs/w0010364.pdf 67970
# 65 chandigarh_pdfs/w0010415.pdf 69120
# 66 chandigarh_pdfs/w0010316.pdf 70210
# 67 chandigarh_pdfs/w0010407.pdf 71306
# 68 chandigarh_pdfs/w0010168.pdf 72303
# 69 chandigarh_pdfs/w0010494.pdf 73450
# 70 chandigarh_pdfs/w0010304.pdf 74630
# 71 chandigarh_pdfs/w0010092.pdf 75549
# 72 chandigarh_pdfs/w0010279.pdf 76663
# 73 chandigarh_pdfs/w0010331.pdf 77849
# 74 chandigarh_pdfs/w0010063.pdf 79231
# 75 chandigarh_pdfs/w0010288.pdf 80582
# 76 chandigarh_pdfs/w0010280.pdf 81700
# 77 chandigarh_pdfs/w0010039.pdf 82728
# 78 chandigarh_pdfs/w0010064.pdf 84203
# 487 chandigarh_pdfs/w0010256.pdf 540655
# 488 chandigarh_pdfs/w0010084.pdf 541791
# 489 chandigarh_pdfs/w0010017.pdf 542848
# 490 chandigarh_pdfs/w0010147.pdf 544030
# 491 chandigarh_pdfs/w0010369.pdf 545358
# 492 chandigarh_pdfs/w0010492.pdf 546432
# 493 chandigarh_pdfs/w0010204.pdf 547509
# 494 chandigarh_pdfs/w0010298.pdf 548734
# 495 chandigarh_pdfs/w0010109.pdf 549975
# 496 chandigarh_pdfs/w0010230.pdf 551471
# 497 chandigarh_pdfs/w0010130.pdf 552531
# 498 chandigarh_pdfs/w0010016.pdf 553804
# 499 chandigarh_pdfs/w0010004.pdf 555151
# 500 chandigarh_pdfs/w0010048.pdf 556370
# 501 chandigarh_pdfs/w0010343.pdf 557266
# 502 chandigarh_pdfs/w0010275.pdf 558407
# 503 chandigarh_pdfs/w0010464.pdf 559554
# 504 chandigarh_pdfs/w0010382.pdf 560693
# 505 chandigarh_pdfs/w0010475.pdf 561772
# 506 chandigarh_pdfs/w0010233.pdf 562852
# 507 chandigarh_pdfs/w0010148.pdf 564058
# 508 chandigarh_pdfs/w0010097.pdf 565014
# 509 chandigarh_pdfs/w0010465.pdf 566031
# 510 chandigarh_pdfs/w0010075.pdf 566862
# 511 chandigarh_pdfs/w0010346.pdf 568021
# 512 chandigarh_pdfs/w0010068.pdf 569510
# 513 chandigarh_pdfs/w0010310.pdf 570649
# 514 chandigarh_pdfs/w0010491.pdf 571477
# 515 chandigarh_pdfs/w0010209.pdf 572578
# 516 chandigarh_pdfs/w0010338.pdf 573662
# 517 chandigarh_pdfs/w0010102.pdf 574727
# 518 chandigarh_pdfs/w0010332.pdf 575904
# 519 chandigarh_pdfs/w0010452.pdf 577076
# 520 chandigarh_pdfs/w0010457.pdf 577881
# 521 chandigarh_pdfs/w0010134.pdf 578965
# 522 chandigarh_pdfs/w0010459.pdf 579933
# 523 chandigarh_pdfs/w0010439.pdf 581071
# 524 chandigarh_pdfs/w0010005.pdf 582353
# 525 chandigarh_pdfs/w0010119.pdf 583632
# 526 chandigarh_pdfs/w0010149.pdf 584578
# 527 chandigarh_pdfs/w0010139.pdf 585728

# %%
df = pd.DataFrame(rows)
df
# Out:
#             filename number          id          elector_name  \
# 0       w0010117.pdf      1  PBA9469131           प्रदीप भनोट
# 1       w0010117.pdf      2  PBA5154240            नीरज शमार्
# 2       w0010117.pdf      3  AXN2315307           हरीश कु मार
# 3       w0010117.pdf      4  PBA7503139        देव कु मार सोइ
# 4       w0010117.pdf      5  PBA8749475           िवक्रम िसंह
# ...              ...    ...         ...                   ...
# 585723  w0010139.pdf   1146  AXN0302364  अशोक कु मार कु करेजा
# 585724  w0010139.pdf   1147  AXN0302349      प्रितभा कु करेजा
# 585725  w0010139.pdf   1148  AXN0302331         जतीन कु करेजा
# 585726  w0010139.pdf   1149  AXN0302356      अपारीता कु करेजा
# 585727  w0010139.pdf   1150  AXN2493674        नुपुर कु करेजा
#
#        father_or_husband_name relationship house_no age    sex
# 0                  एस एन भनोट         िपता        2  60  पुरुष
# 1                    िरखी राम         िपता        2  45  मिहला
# 2                  िबहारी लाल         िपता        2  37  पुरुष
# 3              पृथ्वी राज सोइ         िपता        4  80  पुरुष
# 4                   बलबीर िसह         िपता        4  53  पुरुष
# ...                       ...          ...      ...  ..    ...
# 585723     ज्ञान चन्द कुकरेजा         िपता     3100  59  पुरुष
# 585724     अशोक कुमार कुकरेजा          पित     3100  57  मिहला
# 585725     अशोक कुमार कुकरेजा         िपता     3100  33  पुरुष
# 585726     अशोक कुमार कुकरेजा         िपता     3100  31  मिहला
# 585727           जितन कुकरेजा          पित     3100  29  मिहला
#
# [585728 rows x 9 columns]

# %%
df.relationship.unique()
# Out:
# array(['िपता', 'पित', '......', 'माता'], dtype=object)

# %%
df.sex.unique()
# Out:
# array(['पुरुष', 'मिहला', 'तृतीय'], dtype=object)

# %%
df.age.unique()
# Out:
# array(['60', '45', '37', '80', '53', '69', '63', '55', '52', '30', '26',
#        '74', '46', '38', '73', '50', '48', '19', '76', '54', '32', '31',
#        '57', '33', '25', '72', '66', '58', '36', '68', '51', '23', '27',
#        '24', '61', '47', '40', '91', '64', '67', '65', '42', '41', '22',
#        '35', '20', '39', '43', '79', '85', '77', '21', '81', '28', '56',
#        '44', '70', '29', '49', '59', '34', '82', '78', '75', '88', '62',
#        '86', '92', '83', '71', '89', '87', '90', '84', '96', '93', '94',
#        '97', '95', '100', '103', '102', '99', '105', '101', '98', '111',
#        '104', '112', '106'], dtype=object)

# %%
df.to_csv('/opt/data/searchable_rolls/chandigarh.csv.gz', index_label='index')

# %%
df2 = pd.read_csv('../../parse_in_rolls/csvs/Chandigar_final.csv')
df2
# Out:
#        Unnamed: 0  number            id        elector_name  \
# 0               0     1.0    AXN1387026        माया देवी पु
# 1               1     2.0    AXN1387034  मिनाक्षी पुनिया कप
# 2               2     NaN  3 AXN1386432          कषण चंदर न
# 3               3     4.0    AXN1386457           कलदीपक यु
# 4               4     NaN  > AXN1386465                 NaN
# ...           ...     ...           ...                 ...
# 27429        1211  1215.0    PBA8090821           स॒रताज ये
# 27430        1212  1216.0    PBA8090813             सलीम कप
# 27431        1213  1217.0    AXN0461574             रुबी re
# 27432        1214  1218.0    AXN2111524       जगदीश सिंह re
# 27433        1215  1219.0    AXN1400803      प्रदीप कमार re
#
#        father_or_husband_name relationship house_no  age    sex  \
# 0           राम नाथ पुनिया ——      husband      511   60  महिला
# 1       राम नाथ पुनिया उपलब्ध       father      511   30  महिला
# 2                  श्री चंद a       father      511   54  पुरूष
# 3           कृषण चंदर शर्मा —       father      511   30  पुरूष
# 4      कृषण चंदर कौशिक उपलब्ध       father      511   25  महिला
# ...                       ...          ...      ...  ...    ...
# 27429                 सरदार a       father      NaN   51  पुरूष
# 27430             जाकिर अली a       father      NaN   43  पुरूष
# 27431              सरताज हि 7      husband      0.0   41  महिला
# 27432          मेहरबान सिंह a       father     83.0   50  पुरूष
# 27433      दिनेश कुमार यादव —       father      1.0   26  पुरूष
#
#                ac_name  ...  revenue_division  district  pin_code  \
# 0       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 1       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 2       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 3       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 4       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# ...                ...  ...               ...       ...       ...
# 27429   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27430   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27431   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27432   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27433   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
#
#       polling_station_name                            polling_station_address  \
# 0            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 1            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 2            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 3            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 4            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# ...                    ...                                                ...
# 27429       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27430       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27431       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27432       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27433       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
#
#       net_electors_male net_electors_female net_electors_third_gender  \
# 0                   537                 538                         0
# 1                   537                 538                         0
# 2                   537                 538                         0
# 3                   537                 538                         0
# 4                   537                 538                         0
# ...                 ...                 ...                       ...
# 27429               657                 562                         0
# 27430               657                 562                         0
# 27431               657                 562                         0
# 27432               657                 562                         0
# 27433               657                 562                         0
#
#        net_electors_total original_or_amendment
# 0                    1075              original
# 1                    1075              original
# 2                    1075              original
# 3                    1075              original
# 4                    1075              original
# ...                   ...                   ...
# 27429                1219              original
# 27430                1219              original
# 27431                1219              original
# 27432                1219              original
# 27433                1219              original
#
# [27434 rows x 28 columns]

# %%
df2.id = df2.id.str.strip()
df2
# Out:
#        Unnamed: 0  number            id        elector_name  \
# 0               0     1.0    AXN1387026        माया देवी पु
# 1               1     2.0    AXN1387034  मिनाक्षी पुनिया कप
# 2               2     NaN  3 AXN1386432          कषण चंदर न
# 3               3     4.0    AXN1386457           कलदीपक यु
# 4               4     NaN  > AXN1386465                 NaN
# ...           ...     ...           ...                 ...
# 27429        1211  1215.0    PBA8090821           स॒रताज ये
# 27430        1212  1216.0    PBA8090813             सलीम कप
# 27431        1213  1217.0    AXN0461574             रुबी re
# 27432        1214  1218.0    AXN2111524       जगदीश सिंह re
# 27433        1215  1219.0    AXN1400803      प्रदीप कमार re
#
#        father_or_husband_name relationship house_no  age    sex  \
# 0           राम नाथ पुनिया ——      husband      511   60  महिला
# 1       राम नाथ पुनिया उपलब्ध       father      511   30  महिला
# 2                  श्री चंद a       father      511   54  पुरूष
# 3           कृषण चंदर शर्मा —       father      511   30  पुरूष
# 4      कृषण चंदर कौशिक उपलब्ध       father      511   25  महिला
# ...                       ...          ...      ...  ...    ...
# 27429                 सरदार a       father      NaN   51  पुरूष
# 27430             जाकिर अली a       father      NaN   43  पुरूष
# 27431              सरताज हि 7      husband      0.0   41  महिला
# 27432          मेहरबान सिंह a       father     83.0   50  पुरूष
# 27433      दिनेश कुमार यादव —       father      1.0   26  पुरूष
#
#                ac_name  ...  revenue_division  district  pin_code  \
# 0       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 1       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 2       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 3       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 4       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# ...                ...  ...               ...       ...       ...
# 27429   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27430   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27431   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27432   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27433   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
#
#       polling_station_name                            polling_station_address  \
# 0            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 1            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 2            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 3            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 4            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# ...                    ...                                                ...
# 27429       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27430       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27431       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27432       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27433       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
#
#       net_electors_male net_electors_female net_electors_third_gender  \
# 0                   537                 538                         0
# 1                   537                 538                         0
# 2                   537                 538                         0
# 3                   537                 538                         0
# 4                   537                 538                         0
# ...                 ...                 ...                       ...
# 27429               657                 562                         0
# 27430               657                 562                         0
# 27431               657                 562                         0
# 27432               657                 562                         0
# 27433               657                 562                         0
#
#        net_electors_total original_or_amendment
# 0                    1075              original
# 1                    1075              original
# 2                    1075              original
# 3                    1075              original
# 4                    1075              original
# ...                   ...                   ...
# 27429                1219              original
# 27430                1219              original
# 27431                1219              original
# 27432                1219              original
# 27433                1219              original
#
# [27434 rows x 28 columns]

# %%
df2.elector_name = df2.elector_name.str.strip()
df2
# Out:
#        Unnamed: 0  number            id        elector_name  \
# 0               0     1.0    AXN1387026        माया देवी पु
# 1               1     2.0    AXN1387034  मिनाक्षी पुनिया कप
# 2               2     NaN  3 AXN1386432          कषण चंदर न
# 3               3     4.0    AXN1386457           कलदीपक यु
# 4               4     NaN  > AXN1386465                 NaN
# ...           ...     ...           ...                 ...
# 27429        1211  1215.0    PBA8090821           स॒रताज ये
# 27430        1212  1216.0    PBA8090813             सलीम कप
# 27431        1213  1217.0    AXN0461574             रुबी re
# 27432        1214  1218.0    AXN2111524       जगदीश सिंह re
# 27433        1215  1219.0    AXN1400803      प्रदीप कमार re
#
#        father_or_husband_name relationship house_no  age    sex  \
# 0           राम नाथ पुनिया ——      husband      511   60  महिला
# 1       राम नाथ पुनिया उपलब्ध       father      511   30  महिला
# 2                  श्री चंद a       father      511   54  पुरूष
# 3           कृषण चंदर शर्मा —       father      511   30  पुरूष
# 4      कृषण चंदर कौशिक उपलब्ध       father      511   25  महिला
# ...                       ...          ...      ...  ...    ...
# 27429                 सरदार a       father      NaN   51  पुरूष
# 27430             जाकिर अली a       father      NaN   43  पुरूष
# 27431              सरताज हि 7      husband      0.0   41  महिला
# 27432          मेहरबान सिंह a       father     83.0   50  पुरूष
# 27433      दिनेश कुमार यादव —       father      1.0   26  पुरूष
#
#                ac_name  ...  revenue_division  district  pin_code  \
# 0       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 1       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 2       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 3       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# 4       001 - चण्डीगढ़  ...                 0  चण्डीगढ़    160022
# ...                ...  ...               ...       ...       ...
# 27429   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27430   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27431   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27432   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
# 27433   001 - चण्डीगढ़  ...               198  चण्डीगढ़    160036
#
#       polling_station_name                            polling_station_address  \
# 0            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 1            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 2            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 3            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# 4            246-सैक्टर-35   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 35डी...
# ...                    ...                                                ...
# 27429       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27430       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27431       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27432       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
# 27433       048-ग्राम धनास     राजकीय सीनियर सकैंडरी स्कूल, धनास (कमरा.न. 87)
#
#       net_electors_male net_electors_female net_electors_third_gender  \
# 0                   537                 538                         0
# 1                   537                 538                         0
# 2                   537                 538                         0
# 3                   537                 538                         0
# 4                   537                 538                         0
# ...                 ...                 ...                       ...
# 27429               657                 562                         0
# 27430               657                 562                         0
# 27431               657                 562                         0
# 27432               657                 562                         0
# 27433               657                 562                         0
#
#        net_electors_total original_or_amendment
# 0                    1075              original
# 1                    1075              original
# 2                    1075              original
# 3                    1075              original
# 4                    1075              original
# ...                   ...                   ...
# 27429                1219              original
# 27430                1219              original
# 27431                1219              original
# 27432                1219              original
# 27433                1219              original
#
# [27434 rows x 28 columns]

# %%
df3 = df.merge(df2, on='id')
df3
# Out:
#          filename_x number_x                 id     elector_name_x  \
# 0      w0010309.pdf        1  CH/01/000/1119913      सुिर�द्र िसंह
# 1      w0010309.pdf        2  CH/01/000/1119914    गुिर�द्रजीत कौर
# 2      w0010309.pdf        4         AXN3297181      हरिसमरन कोहली
# 3      w0010309.pdf        5         AXN2593937    तरसेम िसंह िसधु
# 4      w0010309.pdf        7         AXN2593945         नवनीत िसधु
# ...             ...      ...                ...                ...
# 25560  w0010181.pdf     1230         PBA9252313  �याम नारायण गु�ता
# 25561  w0010181.pdf     1231         PBA9252156           परस बैथा
# 25562  w0010181.pdf     1232         PBA9252305          दरोगा शाह
# 25563  w0010181.pdf     1233         PBA9252198     लाल बदन ठाकु र
# 25564  w0010181.pdf     1234         PBA9252248          अशोक बैथा
#
#       father_or_husband_name_x relationship_x     house_no_x age_x  sex_x  \
# 0                   हरबन्स िसह           िपता              1    77  पुरुष
# 1                सुिरन्दर् िसह            पित              1    71  मिहला
# 2                 गुरपर्ीत िसह            पित              1    32  मिहला
# 3                      संत राम           िपता   1/बी 2 फ्लोर    54  पुरुष
# 4               तरसेम िसह िसधु           िपता  1/बी, 2 फ्लोर    24  मिहला
# ...                        ...            ...            ...   ...    ...
# 25560           कीतर् राय गु�ा           िपता              1    52  पुरुष
# 25561             भगराझान बैथा           िपता              1    41  पुरुष
# 25562              रमेश वर शाह           िपता              1    33  पुरुष
# 25563            राम जनक ठाकुर           िपता              1    30  पुरुष
# 25564                कंचन बैथा           िपता              1    28  पुरुष
#
#        Unnamed: 0  ...  revenue_division  district pin_code  \
# 0               0  ...                 0  चण्डीगढ़   160047
# 1               1  ...                 0  चण्डीगढ़   160047
# 2               3  ...                 0  चण्डीगढ़   160047
# 3               4  ...                 0  चण्डीगढ़   160047
# 4               6  ...                 0  चण्डीगढ़   160047
# ...           ...  ...               ...       ...      ...
# 25560        1227  ...                 0  चण्डीगढ़   160026
# 25561        1228  ...                 0  चण्डीगढ़   160026
# 25562        1229  ...                 0  चण्डीगढ़   160026
# 25563        1230  ...                 0  चण्डीगढ़   160026
# 25564        1231  ...                 0  चण्डीगढ़   160026
#
#       polling_station_name                            polling_station_address  \
# 0            309-सैक्टर 44   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 44बी...
# 1            309-सैक्टर 44   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 44बी...
# 2            309-सैक्टर 44   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 44बी...
# 3            309-सैक्टर 44   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 44बी...
# 4            309-सैक्टर 44   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 44बी...
# ...                    ...                                                ...
# 25560        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
# 25561        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
# 25562        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
# 25563        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
# 25564        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
#
#        net_electors_male net_electors_female net_electors_third_gender  \
# 0                    569                 548                         0
# 1                    569                 548                         0
# 2                    569                 548                         0
# 3                    569                 548                         0
# 4                    569                 548                         0
# ...                  ...                 ...                       ...
# 25560                706                 528                         0
# 25561                706                 528                         0
# 25562                706                 528                         0
# 25563                706                 528                         0
# 25564                706                 528                         0
#
#        net_electors_total  original_or_amendment
# 0                    1117               original
# 1                    1117               original
# 2                    1117               original
# 3                    1117               original
# 4                    1117               original
# ...                   ...                    ...
# 25560                1234               original
# 25561                1234               original
# 25562                1234               original
# 25563                1234               original
# 25564                1234               original
#
# [25565 rows x 36 columns]

# %%
df3[df3.elector_name_x==df3.elector_name_y]
# Out:
#          filename_x number_x          id elector_name_x  \
# 646    w0010309.pdf      685  AXN1252063     गगनदीप कौर
# 1167   w0010172.pdf      133  PBA6082507        सगा राम
# 1201   w0010172.pdf      167  PBA4513297           सूरज
# 1534   w0010172.pdf      512  PBA4786976           राजू
# 1563   w0010172.pdf      541  PBA7557408    सूरज प्रकाश
# ...             ...      ...         ...            ...
# 24471  w0010181.pdf       92  PBA8166308   खुषनुमा रानी
# 24605  w0010181.pdf      232  AXN2935229           राजू
# 24696  w0010181.pdf      325  PBA2713287         सुनीता
# 24985  w0010181.pdf      625  AXN2383297         सुनीता
# 25356  w0010181.pdf     1017  PBA2715928           हीरा
#
#       father_or_husband_name_x relationship_x house_no_x age_x  sex_x  \
# 646                  तरसेम िसह           िपता        175    25  मिहला
# 1167                  कालु राम           िपता       3545    71  पुरुष
# 1201                 रणधीर िसह           िपता       3599    39  पुरुष
# 1534                     जगदीश           िपता       3509    30  पुरुष
# 1563                   िशव चरण           िपता       3524    53  पुरुष
# ...                        ...            ...        ...   ...    ...
# 24471           मोहम्मद. मोबीन            पित         18    33  मिहला
# 24605                   रािजदर           िपता         38    21  पुरुष
# 24696                 मु�ा िसह            पित       51बी    36  मिहला
# 24985                  भूप िसह            पित         98    29  मिहला
# 25356                   नािगया            पित        161    33  मिहला
#
#        Unnamed: 0  ...  revenue_division  district pin_code  \
# 646           683  ...                 0  चण्डीगढ़   160047
# 1167          132  ...                 0  चण्डीगढ़   160014
# 1201          166  ...                 0  चण्डीगढ़   160014
# 1534          511  ...                 0  चण्डीगढ़   160014
# 1563          540  ...                 0  चण्डीगढ़   160014
# ...           ...  ...               ...       ...      ...
# 24471          91  ...                 0  चण्डीगढ़   160026
# 24605         231  ...                 0  चण्डीगढ़   160026
# 24696         324  ...                 0  चण्डीगढ़   160026
# 24985         623  ...                 0  चण्डीगढ़   160026
# 25356        1015  ...                 0  चण्डीगढ़   160026
#
#       polling_station_name                            polling_station_address  \
# 646          309-सैक्टर 44   राजकीय माडल सीनियर सकैंडरी स्कूल, सैक्टर 44बी...
# 1167         172-सैक्टर 25   यु.आई.ई.टी. एडमिन. ब्लाक-2 ,सैक्टर 25 (कमरा.न.1)
# 1201         172-सैक्टर 25   यु.आई.ई.टी. एडमिन. ब्लाक-2 ,सैक्टर 25 (कमरा.न.1)
# 1534         172-सैक्टर 25   यु.आई.ई.टी. एडमिन. ब्लाक-2 ,सैक्टर 25 (कमरा.न.1)
# 1563         172-सैक्टर 25   यु.आई.ई.टी. एडमिन. ब्लाक-2 ,सैक्टर 25 (कमरा.न.1)
# ...                    ...                                                ...
# 24471        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
# 24605        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
# 24696        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
# 24985        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
# 25356        181-सैक्टर 26   कम्पोजिट आंगनवाड़ी सैंटर, बापू धाम कालोनी, सै...
#
#        net_electors_male net_electors_female net_electors_third_gender  \
# 646                  569                 548                         0
# 1167                 608                 516                         0
# 1201                 608                 516                         0
# 1534                 608                 516                         0
# 1563                 608                 516                         0
# ...                  ...                 ...                       ...
# 24471                706                 528                         0
# 24605                706                 528                         0
# 24696                706                 528                         0
# 24985                706                 528                         0
# 25356                706                 528                         0
#
#        net_electors_total  original_or_amendment
# 646                  1117               original
# 1167                 1124               original
# 1201                 1124               original
# 1534                 1124               original
# 1563                 1124               original
# ...                   ...                    ...
# 24471                1234               original
# 24605                1234               original
# 24696                1234               original
# 24985                1234               original
# 25356                1234               original
#
# [75 rows x 36 columns]

# %%
df3.to_csv('/tmp/chandigarh_merged.csv', index=False)
